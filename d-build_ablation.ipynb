# %%
import math
import json
from pprint import pprint
from models.model_bank import DynamicOrigami


def calculate_width(P, F, C, A, B):
    """
    Calculate the width (W) of layers in a neural network given the desired number of parameters.
    Parameters:
        - P: int, total number of parameters
        - F: int, number of features (input size)
        - C: int, number of classes (output size)
        - A: int, number of fold layers
        - B: int, total number of linear layers (including the first and last)
    Returns:
        - W: int, calculated width of the layers
    """
    # Coefficients for the quadratic equation
    a = (B - 2)
    b = (F + A + C)
    c = -P

    # Solve the quadratic equation: aW^2 + bW + c = 0
    discriminant = b**2 - 4 * a * c
    if discriminant < 0:
        return 1
    
    try:
        W = (-b + math.sqrt(discriminant)) / (2 * a)
    except ZeroDivisionError:
        W = P / (F + A + C)
    W = max(1, round(W))
    return W



def count_params(n_features, n_classes, min_size=4, scale=2, repeat=6):
    n_params = []
    for i in range(repeat):
        n_params.append(int(n_features * n_classes * min_size * scale**i))
    return n_params



def layer_widths(layers:list, n_features:int, n_classes:int, 
                 min_size:int=8, scale:int=4, repeat:int=6, verbose=0) -> list:
    
    count_linear = sum([1 for layer in layers if "linear" in layer.lower()])
    count_fold = sum([1 for layer in layers if "fold" in layer.lower()])
    
    widths = []
    for i in range(repeat):
        n_params = int(n_features * n_classes * min_size * scale**i)
        widths.append(calculate_width(P=n_params, F=n_features, C=n_classes, A=count_fold, B=count_linear))
    if verbose > 0:
        print("Biggest model:", int(n_params))
    return widths
        
widths = layer_widths(["Linear", "Fold", "Linear", ], 784, 10)
width = widths[0]
print(widths)
# Out:
# [79, 316, 1262, 5049, 20197, 80787]

# %%
ablation_archs = {}
learning_rate = 0.001
soft_fold = True
has_stretch = True
crease = None
fold_in = False
leak = 0
repeat = 5
architectures = [["Linear0", "Linear", "Linear1"], 
                 ["Linear0", "Fold", "Linear1"], 
                 ["Linear0", "Fold", "Linear", "Fold", "Linear1"], 
                 ["Linear0", "Fold", "Linear", "Fold", "Linear", "Fold", "Linear1"], 
                 ["Linear0", "Linear", "Linear", "Linear1"], 
                 ["Fold", "Fold", "Fold", "Fold", "Fold", "Fold", "Fold", "Fold", "Linear1"]]
arch_names = ["3Linear", "21Alt", "32Alt", "43Alt", "4Linear", "8Fold"]
dataset_dims =  [54,        784,        28,     1024,       784]
dataset_ccs =   [7,         10,         2,      10,         10]
dataset_names = ["Cover",   "Digits",   "Higgs", "Cifar10", "Fashion"]

for aname, architecture in zip(arch_names, architectures):
    for dname, input_dim, class_count in zip(dataset_names, dataset_dims, dataset_ccs):
        
        n_params = count_params(input_dim, class_count, min_size=4, scale=2, repeat=5)
        widths = layer_widths(architecture, input_dim, class_count)
        
        for n_param, width in zip(n_params, widths):
 
            name = f"{aname}_{dname}_{n_param}"
            if soft_fold:
                architecture = [layer if layer != "Fold" else "Soft" + layer for layer in architecture]
            arch = {"learning_rate": learning_rate, 
                    "repeat": repeat,
                    "structure": []}
            
            for layer in architecture:
                if "Linear" in layer:
                    if layer[-1] == "0":
                        inf = input_dim
                        out = width
                    elif layer[-1] == "1":
                        inf = width
                        out = class_count
                    else:
                        inf = width
                        out = width
                    arch["structure"].append({"params": {"in_features": inf, 
                                                         "out_features": out}, 
                                              "type": "Linear"})
                else:
                    arch["structure"].append({"params": {"has_stretch": has_stretch,
                                                         "width": width,
                                                         "crease": crease,
                                                         }, 
                                              "type": layer})
            arch["string"] = ["".join(filter(str.isalpha, layer)) for layer in architecture]
            ablation_archs[name] = {"architecture": arch,
                                    "n_classes": class_count,
            }
# save ablation architectures
with open("BenchmarkTests/ablation_archs.json", "w") as f:
    json.dump(ablation_archs, f)
print("Ablation architectures saved.")

pprint(ablation_archs)
# Out:
# Ablation architectures saved.
# {'21Alt_Cifar10_163840': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 1266},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 1266},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 1266,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Cifar10_327680': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 5066},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 5066},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 5066,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Cifar10_40960': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 1024,
#                                                                     'out_features': 79},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 79},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 79,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Cifar10_655360': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 20262},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 20262},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 20262,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Cifar10_81920': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 1024,
#                                                                     'out_features': 317},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 317},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 317,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Cover_12096': {'architecture': {'learning_rate': 0.001,
#                                         'repeat': 5,
#                                         'string': ['Linear',
#                                                    'SoftFold',
#                                                    'Linear'],
#                                         'structure': [{'params': {'in_features': 54,
#                                                                   'out_features': 3122},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 3122},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 3122,
#                                                                   'out_features': 7},
#                                                        'type': 'Linear'}]},
#                        'n_classes': 7},
#  '21Alt_Cover_1512': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 49},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 49},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 49,
#                                                                  'out_features': 7},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 7},
#  '21Alt_Cover_24192': {'architecture': {'learning_rate': 0.001,
#                                         'repeat': 5,
#                                         'string': ['Linear',
#                                                    'SoftFold',
#                                                    'Linear'],
#                                         'structure': [{'params': {'in_features': 54,
#                                                                   'out_features': 12486},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 12486},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 12486,
#                                                                   'out_features': 7},
#                                                        'type': 'Linear'}]},
#                        'n_classes': 7},
#  '21Alt_Cover_3024': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 195},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 195},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 195,
#                                                                  'out_features': 7},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 7},
#  '21Alt_Cover_6048': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 780},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 780},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 780,
#                                                                  'out_features': 7},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 7},
#  '21Alt_Digits_125440': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 784,
#                                                                     'out_features': 1262},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 1262},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 1262,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Digits_250880': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 784,
#                                                                     'out_features': 5049},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 5049},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 5049,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Digits_31360': {'architecture': {'learning_rate': 0.001,
#                                          'repeat': 5,
#                                          'string': ['Linear',
#                                                     'SoftFold',
#                                                     'Linear'],
#                                          'structure': [{'params': {'in_features': 784,
#                                                                    'out_features': 79},
#                                                         'type': 'Linear'},
#                                                        {'params': {'crease': None,
#                                                                    'has_stretch': True,
#                                                                    'width': 79},
#                                                         'type': 'SoftFold'},
#                                                        {'params': {'in_features': 79,
#                                                                    'out_features': 10},
#                                                         'type': 'Linear'}]},
#                         'n_classes': 10},
#  '21Alt_Digits_501760': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 784,
#                                                                     'out_features': 20197},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 20197},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 20197,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Digits_62720': {'architecture': {'learning_rate': 0.001,
#                                          'repeat': 5,
#                                          'string': ['Linear',
#                                                     'SoftFold',
#                                                     'Linear'],
#                                          'structure': [{'params': {'in_features': 784,
#                                                                    'out_features': 316},
#                                                         'type': 'Linear'},
#                                                        {'params': {'crease': None,
#                                                                    'has_stretch': True,
#                                                                    'width': 316},
#                                                         'type': 'SoftFold'},
#                                                        {'params': {'in_features': 316,
#                                                                    'out_features': 10},
#                                                         'type': 'Linear'}]},
#                         'n_classes': 10},
#  '21Alt_Fashion_125440': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 784,
#                                                                      'out_features': 1262},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 1262},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 1262,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Fashion_250880': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 784,
#                                                                      'out_features': 5049},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 5049},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 5049,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Fashion_31360': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 784,
#                                                                     'out_features': 79},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 79},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 79,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Fashion_501760': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 784,
#                                                                      'out_features': 20197},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 20197},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 20197,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '21Alt_Fashion_62720': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 784,
#                                                                     'out_features': 316},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 316},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 316,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '21Alt_Higgs_1792': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 28,
#                                                                  'out_features': 925},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 925},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 925,
#                                                                  'out_features': 2},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 2},
#  '21Alt_Higgs_224': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['Linear',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'in_features': 28,
#                                                                 'out_features': 14},
#                                                      'type': 'Linear'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 14},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 14,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2},
#  '21Alt_Higgs_3584': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 28,
#                                                                  'out_features': 3700},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 3700},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 3700,
#                                                                  'out_features': 2},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 2},
#  '21Alt_Higgs_448': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['Linear',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'in_features': 28,
#                                                                 'out_features': 58},
#                                                      'type': 'Linear'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 58},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 58,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2},
#  '21Alt_Higgs_896': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['Linear',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'in_features': 28,
#                                                                 'out_features': 231},
#                                                      'type': 'Linear'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 231},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 231,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2},
#  '32Alt_Cifar10_163840': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 739},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 739},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 739,
#                                                                      'out_features': 739},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 739},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 739,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '32Alt_Cifar10_327680': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 1830},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 1830},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 1830,
#                                                                      'out_features': 1830},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 1830},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 1830,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '32Alt_Cifar10_40960': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 1024,
#                                                                     'out_features': 74},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 74},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 74,
#                                                                     'out_features': 74},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 74},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 74,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '32Alt_Cifar10_655360': {'architecture': {'learning_rate': 0.001,
#                                            'repeat': 5,
#                                            'string': ['Linear',
#                                                       'SoftFold',
#                                                       'Linear',
#                                                       'SoftFold',
#                                                       'Linear'],
#                                            'structure': [{'params': {'in_features': 1024,
#                                                                      'out_features': 4091},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 4091},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 4091,
#                                                                      'out_features': 4091},
#                                                           'type': 'Linear'},
#                                                          {'params': {'crease': None,
#                                                                      'has_stretch': True,
#                                                                      'width': 4091},
#                                                           'type': 'SoftFold'},
#                                                          {'params': {'in_features': 4091,
#                                                                      'out_features': 10},
#                                                           'type': 'Linear'}]},
#                           'n_classes': 10},
#  '32Alt_Cifar10_81920': {'architecture': {'learning_rate': 0.001,
#                                           'repeat': 5,
#                                           'string': ['Linear',
#                                                      'SoftFold',
#                                                      'Linear',
#                                                      'SoftFold',
#                                                      'Linear'],
#                                           'structure': [{'params': {'in_features': 1024,
#                                                                     'out_features': 254},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 254},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 254,
#                                                                     'out_features': 254},
#                                                          'type': 'Linear'},
#                                                         {'params': {'crease': None,
#                                                                     'has_stretch': True,
#                                                                     'width': 254},
#                                                          'type': 'SoftFold'},
#                                                         {'params': {'in_features': 254,
#                                                                     'out_features': 10},
#                                                          'type': 'Linear'}]},
#                          'n_classes': 10},
#  '32Alt_Cover_12096': {'architecture': {'learning_rate': 0.001,
#                                         'repeat': 5,
#                                         'string': ['Linear',
#                                                    'SoftFold',
#                                                    'Linear',
#                                                    'SoftFold',
#                                                    'Linear'],
#                                         'structure': [{'params': {'in_features': 54,
#                                                                   'out_features': 410},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 410},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 410,
#                                                                   'out_features': 410},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 410},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 410,
#                                                                   'out_features': 7},
#                                                        'type': 'Linear'}]},
#                        'n_classes': 7},
#  '32Alt_Cover_1512': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 32},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 32},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 32,
#                                                                  'out_features': 32},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 32},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 32,
#                                                                  'out_features': 7},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 7},
#  '32Alt_Cover_24192': {'architecture': {'learning_rate': 0.001,
#                                         'repeat': 5,
#                                         'string': ['Linear',
#                                                    'SoftFold',
#                                                    'Linear',
#                                                    'SoftFold',
#                                                    'Linear'],
#                                         'structure': [{'params': {'in_features': 54,
#                                                                   'out_features': 849},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 849},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 849,
#                                                                   'out_features': 849},
#                                                        'type': 'Linear'},
#                                                       {'params': {'crease': None,
#                                                                   'has_stretch': True,
#                                                                   'width': 849},
#                                                        'type': 'SoftFold'},
#                                                       {'params': {'in_features': 849,
#                                                                   'out_features': 7},
#                                                        'type': 'Linear'}]},
#                        'n_classes': 7},
#  '32Alt_Cover_3024': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 83},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 83},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 83,
#                                                                  'out_features': 83},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 83},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 83,
#                                                                  'out_features': 7},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 7},
#  '32Alt_Cover_6048': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['Linear',
#                                                   'SoftFold',
#                                                   'Linear',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'in_features': 54,
#                                                                  'out_features': 191},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 191},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 191,
#                                                                  'out_features': 191},
#                                                       'type': 'Linear'},
#                                                      {'params': {'crease': None,
# ...
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 1,
#                                                                  'out_features': 2},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 2},
#  '8Fold_Higgs_224': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 1,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2},
#  '8Fold_Higgs_3584': {'architecture': {'learning_rate': 0.001,
#                                        'repeat': 5,
#                                        'string': ['SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'SoftFold',
#                                                   'Linear'],
#                                        'structure': [{'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'crease': None,
#                                                                  'has_stretch': True,
#                                                                  'width': 1},
#                                                       'type': 'SoftFold'},
#                                                      {'params': {'in_features': 1,
#                                                                  'out_features': 2},
#                                                       'type': 'Linear'}]},
#                       'n_classes': 2},
#  '8Fold_Higgs_448': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 1,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2},
#  '8Fold_Higgs_896': {'architecture': {'learning_rate': 0.001,
#                                       'repeat': 5,
#                                       'string': ['SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'SoftFold',
#                                                  'Linear'],
#                                       'structure': [{'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'crease': None,
#                                                                 'has_stretch': True,
#                                                                 'width': 1},
#                                                      'type': 'SoftFold'},
#                                                     {'params': {'in_features': 1,
#                                                                 'out_features': 2},
#                                                      'type': 'Linear'}]},
#                      'n_classes': 2}}

# %%
old_archs = json.load(open("BenchmarkTests/architectures.json", "r"))
read_idx = 15
for i, (name, info) in enumerate(old_archs.items()):
    if i == read_idx:
        pprint(info)
        break
# Out:
# {'learning_rate': 0.01,
#  'repeat': 3,
#  'string': ['SoftFold', 'SoftFold', 'SoftFold', 'Linear'],
#  'structure': [{'params': {'has_stretch': False, 'width': 1.1},
#                 'type': 'SoftFold'},
#                {'params': {'has_stretch': False, 'width': 1.1},
#                 'type': 'SoftFold'},
#                {'params': {'has_stretch': False, 'width': 1.1},
#                 'type': 'SoftFold'},
#                {'params': {'in_features': 1.1, 'out_features': 1.1},
#                 'type': 'Linear'}]}

# %%
# load ablation architectures
ablation_archs = json.load(open("BenchmarkTests/ablation_archs.json", "r"))
for name, info in ablation_archs.items():
    print(name, end=":\t")
    model = DynamicOrigami(info["architecture"]["structure"], info["n_classes"], iknowaboutthecutlayer=True)
    print("Succeeded.")
# Out:
# FullLinear_Cover_1512:	Succeeded.
# FullLinear_Cover_3024:	Succeeded.
# FullLinear_Cover_6048:	Succeeded.
# FullLinear_Cover_12096:	Succeeded.
# FullLinear_Cover_24192:	Succeeded.
# FullLinear_Digits_31360:	Succeeded.
# FullLinear_Digits_62720:	Succeeded.
# FullLinear_Digits_125440:	Succeeded.
# FullLinear_Digits_250880:	Succeeded.
# FullLinear_Digits_501760:	Succeeded.
# FullLinear_Higgs_224:	Succeeded.
# FullLinear_Higgs_448:	Succeeded.
# FullLinear_Higgs_896:	Succeeded.
# FullLinear_Higgs_1792:	Succeeded.
# FullLinear_Higgs_3584:	Succeeded.
# FullLinear_Cifar10_40960:	Succeeded.
# FullLinear_Cifar10_81920:	Succeeded.
# FullLinear_Cifar10_163840:	Succeeded.
# FullLinear_Cifar10_327680:	Succeeded.
# FullLinear_Cifar10_655360:	Succeeded.
# FullLinear_Fashion_31360:	Succeeded.
# FullLinear_Fashion_62720:	Succeeded.
# FullLinear_Fashion_125440:	Succeeded.
# FullLinear_Fashion_250880:	Succeeded.
# FullLinear_Fashion_501760:	Succeeded.
# 21Alt_Cover_1512:	Succeeded.
# 21Alt_Cover_3024:	Succeeded.
# 21Alt_Cover_6048:	Succeeded.
# 21Alt_Cover_12096:	Succeeded.
# 21Alt_Cover_24192:	Succeeded.
# 21Alt_Digits_31360:	Succeeded.
# 21Alt_Digits_62720:	Succeeded.
# 21Alt_Digits_125440:	Succeeded.
# 21Alt_Digits_250880:	Succeeded.
# 21Alt_Digits_501760:	Succeeded.
# 21Alt_Higgs_224:	Succeeded.
# 21Alt_Higgs_448:	Succeeded.
# 21Alt_Higgs_896:	Succeeded.
# 21Alt_Higgs_1792:	Succeeded.
# 21Alt_Higgs_3584:	Succeeded.
# 21Alt_Cifar10_40960:	Succeeded.
# 21Alt_Cifar10_81920:	Succeeded.
# 21Alt_Cifar10_163840:	Succeeded.
# 21Alt_Cifar10_327680:	Succeeded.
# 21Alt_Cifar10_655360:	Succeeded.
# 21Alt_Fashion_31360:	Succeeded.
# 21Alt_Fashion_62720:	Succeeded.
# 21Alt_Fashion_125440:	Succeeded.
# 21Alt_Fashion_250880:	Succeeded.
# 21Alt_Fashion_501760:	Succeeded.
# 32Alt_Cover_1512:	Succeeded.
# 32Alt_Cover_3024:	Succeeded.
# 32Alt_Cover_6048:	Succeeded.
# 32Alt_Cover_12096:	Succeeded.
# 32Alt_Cover_24192:	Succeeded.
# 32Alt_Digits_31360:	Succeeded.
# 32Alt_Digits_62720:	Succeeded.
# 32Alt_Digits_125440:	Succeeded.
# 32Alt_Digits_250880:	Succeeded.
# 32Alt_Digits_501760:	Succeeded.
# 32Alt_Higgs_224:	Succeeded.
# 32Alt_Higgs_448:	Succeeded.
# 32Alt_Higgs_896:	Succeeded.
# 32Alt_Higgs_1792:	Succeeded.
# 32Alt_Higgs_3584:	Succeeded.
# 32Alt_Cifar10_40960:	Succeeded.
# 32Alt_Cifar10_81920:	Succeeded.
# 32Alt_Cifar10_163840:	Succeeded.
# 32Alt_Cifar10_327680:	Succeeded.
# 32Alt_Cifar10_655360:	Succeeded.
# 32Alt_Fashion_31360:	Succeeded.
# 32Alt_Fashion_62720:	Succeeded.
# 32Alt_Fashion_125440:	Succeeded.
# 32Alt_Fashion_250880:	Succeeded.
# 32Alt_Fashion_501760:	Succeeded.
# 43Alt_Cover_1512:	Succeeded.
# 43Alt_Cover_3024:	Succeeded.
# 43Alt_Cover_6048:	Succeeded.
# 43Alt_Cover_12096:	Succeeded.
# 43Alt_Cover_24192:	Succeeded.
# 43Alt_Digits_31360:	Succeeded.
# 43Alt_Digits_62720:	Succeeded.
# 43Alt_Digits_125440:	Succeeded.
# 43Alt_Digits_250880:	Succeeded.
# 43Alt_Digits_501760:	Succeeded.
# 43Alt_Higgs_224:	Succeeded.
# 43Alt_Higgs_448:	Succeeded.
# 43Alt_Higgs_896:	Succeeded.
# 43Alt_Higgs_1792:	Succeeded.
# 43Alt_Higgs_3584:	Succeeded.
# 43Alt_Cifar10_40960:	Succeeded.
# 43Alt_Cifar10_81920:	Succeeded.
# 43Alt_Cifar10_163840:	Succeeded.
# 43Alt_Cifar10_327680:	Succeeded.
# 43Alt_Cifar10_655360:	Succeeded.
# 43Alt_Fashion_31360:	Succeeded.
# 43Alt_Fashion_62720:	Succeeded.
# 43Alt_Fashion_125440:	Succeeded.
# 43Alt_Fashion_250880:	Succeeded.
# 43Alt_Fashion_501760:	Succeeded.
# FullFold_Cover_1512:	Succeeded.
# FullFold_Cover_3024:	Succeeded.
# FullFold_Cover_6048:	Succeeded.
# FullFold_Cover_12096:	Succeeded.
# FullFold_Cover_24192:	Succeeded.
# FullFold_Digits_31360:	Succeeded.
# FullFold_Digits_62720:	Succeeded.
# FullFold_Digits_125440:	Succeeded.
# FullFold_Digits_250880:	Succeeded.
# FullFold_Digits_501760:	Succeeded.
# FullFold_Higgs_224:	Succeeded.
# FullFold_Higgs_448:	Succeeded.
# FullFold_Higgs_896:	Succeeded.
# FullFold_Higgs_1792:	Succeeded.
# FullFold_Higgs_3584:	Succeeded.
# FullFold_Cifar10_40960:	Succeeded.
# FullFold_Cifar10_81920:	Succeeded.
# FullFold_Cifar10_163840:	Succeeded.
# FullFold_Cifar10_327680:	Succeeded.
# FullFold_Cifar10_655360:	Succeeded.
# FullFold_Fashion_31360:	Succeeded.
# FullFold_Fashion_62720:	Succeeded.
# FullFold_Fashion_125440:	Succeeded.
# FullFold_Fashion_250880:	Succeeded.
# FullFold_Fashion_501760:	Succeeded.
