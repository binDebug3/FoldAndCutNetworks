# %%
import numpy as np

# %%
# load in the data from the .npy file
filename = 'train_acc_i0_d241122@1053.npy'
foldername = 'Increasing_SoftFold_depth_1_rate_0.1_stretch_0_lr0.01'
data = np.load('results/covtype/' + foldername + '/npy_files/' + filename)
# data = np.load('results/covtype/Increasing_SoftFold_depth_1_rate_0.1_stretch_0_lr0.01/npy_files/train_acc_i0_d241122@1053.npy')

data
# Out:
# array([11.79270527,  6.77184662,  8.67293806,  4.99181001,  5.20918699,
#         7.00677982,  7.97599739,  9.00078868, 10.32912463, 10.77191561,
#         6.59723754,  6.54238149,  4.85331127, 11.65260168,  8.40369151,
#         6.81410386,  8.81633244, 13.64068882,  9.3746656 ,  7.09225892,
#         5.80924092,  5.10270185,  8.77450318,  8.21367317,  7.6447714 ])

# %%
poo = {'a':1, 'b':2}
pee = {'a':3, 'd':4}
poo.update(pee)
poo
# Out:
# {'a': 3, 'b': 2, 'd': 4}

# %%
from experimenter import *
import datetime as dt
date_format = "%y%m%d@%H%M"
date_time = dt.datetime.now().strftime(date_format)
dataset_name = "fashionMNIST"
plot_results({}, ([], date_time, dataset_name), repeat=3, verbose=0, save_fig=False, scale=5, fontsize=8)
# Out:
# {0: [0.6747749999999999, 0.8767261904761904], 1: [0.6855294642857143, 0.9973005952380952], 2: [9.037194282776968, 211.01697611000424], 3: [1.4113727458087463e-05, 3.0451317375991495e-05], 4: [7065.0, 10442.3]}
# 2it [00:00, 28.38it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parameters for the grid size
rows, cols = 4, 5

# Create the subplot grid
plt.figure(figsize=(15, 10))
for i in range(rows * cols):
    plt.subplot(rows, cols, i + 1)
    plt.plot(np.random.rand(10))  # Example plot

# Add adaptive column titles
column_titles = [f"Column {i+1}" for i in range(cols)]  # Define titles for each column
top_margin = 0.92  # Adjust this to control the vertical position of column titles
for i, col_title in enumerate(column_titles):
    # Calculate the horizontal position of each title
    x_pos = (i + 0.5) / cols  # Center titles in each column
    plt.figtext(x_pos, top_margin, col_title, ha='center', fontsize=14, weight='bold')

# Adjust the layout to leave space for the titles
plt.subplots_adjust(top=0.85)  # Adjust `top` to control overall layout spacing
plt.tight_layout()
plt.show()

# %%
ex = list(t.keys())[0]
t[ex]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ex = list(t.keys())[0]
#       2 t[ex]
#
# NameError: name 't' is not defined
