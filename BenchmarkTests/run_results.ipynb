# %%
import numpy as np

# %%
# load in the data from the .npy file
filename = 'train_acc_i0_d241122@1053.npy'
foldername = 'Increasing_SoftFold_depth_1_rate_0.1_stretch_0_lr0.01'
data = np.load('results/covtype/' + foldername + '/npy_files/' + filename)
# data = np.load('results/covtype/Increasing_SoftFold_depth_1_rate_0.1_stretch_0_lr0.01/npy_files/train_acc_i0_d241122@1053.npy')

data
# Out:
# array([11.79270527,  6.77184662,  8.67293806,  4.99181001,  5.20918699,
#         7.00677982,  7.97599739,  9.00078868, 10.32912463, 10.77191561,
#         6.59723754,  6.54238149,  4.85331127, 11.65260168,  8.40369151,
#         6.81410386,  8.81633244, 13.64068882,  9.3746656 ,  7.09225892,
#         5.80924092,  5.10270185,  8.77450318,  8.21367317,  7.6447714 ])

# %%
poo = {'a':1, 'b':2}
pee = {'a':3, 'd':4}
poo.update(pee)
poo
# Out:
# {'a': 3, 'b': 2, 'd': 4}

# %%
from experimenter import *
import datetime as dt
date_format = "%y%m%d@%H%M"
date_time = dt.datetime.now().strftime(date_format)
dataset_name = "covtype"
t, v = plot_results({}, ([], date_time, dataset_name), repeat=3, verbose=0, save_fig=False)

# %%
ex = list(t.keys())[0]
t[ex]
# Out:
# {'mean': {'loss': array([0.52813396, 0.61024814, 0.6180938 , 0.62412507, 0.62820568,
#          0.62976908, 0.63010614, 0.63008462, 0.63157631, 0.63130379,
#          0.63135399, 0.63554217, 0.63579317, 0.63236517, 0.633821  ,
#          0.6363669 , 0.63348394, 0.63784423, 0.63716294, 0.6369191 ,
#          0.63242255, 0.63783706, 0.63691193, 0.63540591, 0.63567126,
#          0.63546328, 0.63498279, 0.63829604, 0.63869048, 0.63770797,
#          0.63776535, 0.63943632, 0.64067699, 0.63892714, 0.64138698,
#          0.63570711, 0.64015347, 0.63749283, 0.63716294, 0.64015347,
#          0.64021084, 0.63699082, 0.63716294, 0.63880522, 0.6386331 ,
#          0.640928  , 0.63836776, 0.63894148, 0.63960843, 0.64230493,
#          0.64150889, 0.63746414, 0.64064831, 0.64144435, 0.63634538,
#          0.64340935, 0.64418388, 0.64259897, 0.6393646 , 0.63895582,
#          0.63909208, 0.64069851, 0.63795181, 0.64068417, 0.64425559,
#          0.64403328, 0.64236948, 0.63942915, 0.64179575, 0.64307946,
#          0.64145152, 0.6417599 , 0.63667527, 0.64741107, 0.63998853]),
#   'acc': array([0.99458045, 1.04944857, 1.1405031 , 1.06991872, 1.21306819,
#          1.41538481, 0.99953764, 1.27668502, 1.39778993, 1.06067287,
#          1.09216624, 1.4086717 , 1.33759438, 0.83144707, 1.04586461,
#          0.9966262 , 1.10564419, 0.92740297, 1.0154967 , 0.97161999,
#          0.88018925, 1.38226837, 1.28350945, 1.28153086, 0.98848067]),
#   'time': 1.4519676603125734e-05,
#   'params': 385.0},
#  'std': {'loss': array([0.01606838, 0.00507932, 0.00410326, 0.00176868, 0.00521545,
#          0.00637066, 0.00209811, 0.00352286, 0.00527801, 0.00270953,
#          0.00179182, 0.00430189, 0.00275058, 0.00309518, 0.00202558,
#          0.00331467, 0.00385908, 0.00158363, 0.00442638, 0.00177057,
#          0.00181651, 0.00062165, 0.00273917, 0.0006863 , 0.00529898,
#          0.00131472, 0.00187716, 0.00365804, 0.00288528, 0.00391197,
#          0.00493932, 0.00249872, 0.00142521, 0.00314758, 0.00231762,
#          0.00121316, 0.00154869, 0.00446076, 0.00493948, 0.00316113,
#          0.00148446, 0.00175537, 0.00107736, 0.00579124, 0.00235428,
#          0.00199923, 0.00307111, 0.00143047, 0.00372164, 0.002     ,
#          0.00063272, 0.00332062, 0.00305075, 0.00039955, 0.00138111,
#          0.00382054, 0.00052298, 0.00118584, 0.00339324, 0.00387464,
#          0.00243645, 0.00286246, 0.0029186 , 0.0036119 , 0.0031401 ,
#          0.00328103, 0.00338732, 0.00294063, 0.00201996, 0.00371522,
#          0.00313387, 0.00132706, 0.00124219, 0.00234844, 0.00088347]),
#   'acc': array([0.05764081, 0.09752367, 0.24848768, 0.1888195 , 0.18139079,
#          0.36485758, 0.1071657 , 0.11382102, 0.38325054, 0.1828436 ,
#          0.17148876, 0.28903587, 0.42471771, 0.03198356, 0.16936132,
#          0.14697285, 0.16565847, 0.09216677, 0.13597564, 0.0818969 ,
#          0.02767579, 0.39778778, 0.2945972 , 0.31595523, 0.13443231]),
#   'time': 1.709061141251206e-07,
#   'params': array(0.)}}
